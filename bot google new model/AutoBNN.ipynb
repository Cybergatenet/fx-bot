# %% [markdown]
# # Auto Bayesian Neural Networks

# %%
import pandas as pd
dfo = pd.read_csv("EURUSD_Candlestick_1_Hour_BID_01.07.2020-15.07.2023.csv")
dfo=dfo[dfo['Volume']!=0]
dfo.reset_index(drop=True, inplace=True)
dfo.head(10)
# Out:
#                   Gmt time     Open     High      Low    Close      Volume
# 0  01.07.2020 00:00:00.000  1.12336  1.12336  1.12275  1.12306   4148.0298
# 1  01.07.2020 01:00:00.000  1.12306  1.12395  1.12288  1.12385   5375.5801
# 2  01.07.2020 02:00:00.000  1.12386  1.12406  1.12363  1.12382   4131.6099
# 3  01.07.2020 03:00:00.000  1.12382  1.12388  1.12221  1.12265   4440.6001
# 4  01.07.2020 04:00:00.000  1.12265  1.12272  1.12151  1.12179   4833.1001
# 5  01.07.2020 05:00:00.000  1.12179  1.12261  1.12156  1.12240   6689.5601
# 6  01.07.2020 06:00:00.000  1.12240  1.12343  1.12202  1.12333   7562.7500
# 7  01.07.2020 07:00:00.000  1.12331  1.12331  1.12231  1.12315   8641.7500
# 8  01.07.2020 08:00:00.000  1.12315  1.12448  1.12290  1.12311  10042.7695
# 9  01.07.2020 09:00:00.000  1.12313  1.12337  1.12076  1.12076   9587.4004

# %%
dfo['Gmt time'] = pd.to_datetime(dfo['Gmt time'], format='%d.%m.%Y %H:%M:%S.%f')

# %%
def label_data(df, lookahead=5, threshold=0.002):
    """
    Labels each candle based on future closing price percentage change.

    Parameters:
    -----------
    df : pd.DataFrame
        Data containing at least a 'Close' column.
    lookahead : int, optional
        Number of candles to look ahead (default is 5).
    threshold : float, optional
        Percentage change threshold for classification (default is 0.002 or 0.2%).
    """
    
    # Compute future percentage change in closing price
    df["future_return"] = df["Close"].pct_change(lookahead).shift(-lookahead)

    # Assign labels
    df["label"] = 0  # Default: Neutral
    df.loc[df["future_return"] > threshold, "label"] = 2  # Up
    df.loc[df["future_return"] < -threshold, "label"] = 1  # Down

    # Drop future_return column (not needed in final output)
    df.drop(columns=["future_return"], inplace=True)

# %%
label_data(dfo)

# %%
dfo[dfo["label"]!=0]
# Out:
#                  Gmt time     Open     High      Low    Close      Volume  \
# 6     2020-07-01 06:00:00  1.12240  1.12343  1.12202  1.12333   7562.7500
# 9     2020-07-01 09:00:00  1.12313  1.12337  1.12076  1.12076   9587.4004
# 10    2020-07-01 10:00:00  1.12076  1.12113  1.12002  1.12050  11767.5898
# 11    2020-07-01 11:00:00  1.12050  1.12067  1.11848  1.12036  14733.7998
# 12    2020-07-01 12:00:00  1.12036  1.12209  1.11980  1.12177  13410.0596
# ...                   ...      ...      ...      ...      ...         ...
# 17735 2023-07-13 12:00:00  1.11742  1.11897  1.11615  1.11795  39235.5900
# 17736 2023-07-13 13:00:00  1.11797  1.11949  1.11761  1.11942  35069.8900
# 17737 2023-07-13 14:00:00  1.11943  1.11959  1.11806  1.11957  26614.8000
# 17738 2023-07-13 15:00:00  1.11959  1.11965  1.11858  1.11927  20519.5900
# 17748 2023-07-14 01:00:00  1.12227  1.12336  1.12221  1.12329  19807.7400
#
#        label
# 6          1
# 9          2
# 10         2
# 11         2
# 12         2
# ...      ...
# 17735      2
# 17736      2
# 17737      2
# 17738      2
# 17748      1
#
# [4753 rows x 7 columns]

# %%
import numpy as np
import pandas as pd
import autobnn as ab
import jax
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

def create_sliding_window_dataset(df, window_size=50, lookahead=5, threshold=0.002):
    if "Close" not in df.columns or "label" not in df.columns:
        raise ValueError("DataFrame must contain 'Close' and 'label' columns.")

    label_data(df=df, lookahead=lookahead, threshold=threshold)

    close_prices = df["Close"].values
    labels = df["label"].values

    n_samples = len(df) - window_size
    if n_samples <= 0:
        raise ValueError("Not enough data to create even one window."
                         "Increase your dataset or decrease window_size.")

    X_list = []
    y_list = []

    for i in range(n_samples):
        window_data = close_prices[i : i + window_size]
        last_candle_label = labels[i + window_size - 1] # label of the last candle in window_size
        X_list.append(window_data)
        y_list.append(last_candle_label)

    X = np.array(X_list)
    y = np.array(y_list)

    return X, y

# %%
X, y = create_sliding_window_dataset(dfo)
len(X[0])
# Out:
# 50

# %%
import jax
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import autobnn as ab
from autobnn import estimators, operators, kernels

def walk_forward_autobnn_ovr(
    df, 
    window_size=100,
    train_size=50,
    step_size=5,
    threshold=0.002,
    n_classes=3  # e.g., if labels are {0,1,2}
):
    """
    Multi-class classification via One-vs-Rest using AutoBNN,
    specifically using 'normal_likelihood_logistic_noise' for each binary classifier.
    
    Steps:
      1) create_sliding_window_dataset(...) -> (X, y)
         X: (n_samples, n_features), y: (n_samples,) with integer classes
      2) For each walk-forward iteration:
         - Train n_classes binary models, each "Does y == c?" -> 0/1
         - At prediction time, get each model's 'logit' => logistic transform => probability
         - Argmax over classes => final predicted class
      3) Return single-sample accuracies for each step.
    """

    # 1. Build your dataset
    X, y = create_sliding_window_dataset(df=df, window_size=window_size, threshold=threshold)
    n_total = len(X)
    # print(X, n_total)
    if n_total < train_size + 1:
        raise ValueError("Not enough samples for walk-forward analysis.")

    accuracies = []

    # 2. Walk-forward loop
    for i in range(0, n_total - train_size, step_size):
        X_train = X[i : i + train_size]
        y_train = y[i : i + train_size]

        test_index = i + train_size
        if test_index >= n_total:
            break

        X_test = X[test_index : test_index + 1]  # shape (1, features)
        y_test = y[test_index : test_index + 1]  # shape (1,)

        # Scale
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled  = scaler.transform(X_test)

        # 3. Train one binary model per class
        estimators = []
        for c in range(n_classes):
            # Make binary labels: 1 if y == c, else 0
            y_train_c = (y_train == c).astype(int)

            model_c = ab.operators.Add(
                bnns=(
                    ab.kernels.PeriodicBNN(width=20, period=12.0),
                    ab.kernels.LinearBNN(width=20),
                    ab.kernels.MaternBNN(width=20),
                )
            )
            # Use the likelihood your autobnn version actually recognizes:
            # 'normal_likelihood_logistic_noise' is a hacky approach but workable if recognized.
            estimator_c = ab.estimators.AutoBnnMapEstimator(
                model_c,
                likelihood_model="normal_likelihood_logistic_noise",  
                seed=jax.random.PRNGKey(42),
                periods=[12],
                # We do not set k=2 because it's not a pure classification wrapper,
                # but you can pass k=2 if your version allows it. 
            )

            estimator_c.fit(X_train_scaled, y_train_c)
            estimators.append(estimator_c)

        # 4. Predict probabilities for each class on the single test sample
        #    'normal_likelihood_logistic_noise' typically returns shape (1,2): [mean, var]
        #    We'll interpret the 'mean' as a *logit*, i.e. log-odds, and do logistic transform.
        class_probs = []
        for c in range(n_classes):
            y_pred_c = estimators[c].predict(X_test_scaled)  # shape (1,2) or (1,)?
            
            # If it returns shape (1,2) => [ [mean, var] ],
            # we take the 0th column as mean (the "logit").
            # In some versions, it might be shape (1,) -> just the mean. 
            if y_pred_c.ndim == 2:
                logit = y_pred_c[0, 0]  # first row, mean col
            else:
                # shape (1,) => just the mean
                logit = y_pred_c[0]
            
            # Convert logit -> probability: prob = 1 / (1 + exp(-logit))
            prob_c = 1.0 / (1.0 + np.exp(-logit))
            class_probs.append(prob_c)

        # 5. Pick the class with the highest probability
        y_pred_class = np.argmax(class_probs)  # integer c in [0..n_classes-1]

        # 6. Single-sample accuracy (0 or 1)
        acc = accuracy_score(y_test, [y_pred_class])
        accuracies.append(acc)

    return accuracies

dfsample = dfo[:1000].copy()

# Example usage:
results = walk_forward_autobnn_ovr(
    df=dfsample,
    window_size=40,
    train_size=20,
    step_size=5,
    threshold=0.002,
    n_classes=3  # e.g. for classes {0,1,2}
)

print("Accuracies:", results)
if results:
    print("Mean Accuracy:", np.mean(results))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 116
#     113 dfsample = dfo[:1000].copy()
#     115 # Example usage:
# --> 116 results = walk_forward_autobnn_ovr(
#     117     df=dfsample,
#     118     window_size=40,
#     119     train_size=20,
#     120     step_size=5,
#     121     threshold=0.002,
#     122     n_classes=3  # e.g. for classes {0,1,2}
#     123 )
#     125 print("Accuracies:", results)
#     126 if results:
#
# Cell In[8], line 81, in walk_forward_autobnn_ovr(df, window_size, train_size, step_size, threshold, n_classes)
#      70     # Use the likelihood your autobnn version actually recognizes:
#      71     # 'normal_likelihood_logistic_noise' is a hacky approach but workable if recognized.
#      72     estimator_c = ab.estimators.AutoBnnMapEstimator(
#      73         model_c,
#      74         likelihood_model="normal_likelihood_logistic_noise",
#    (...)
#      78         # but you can pass k=2 if your version allows it.
#      79     )
# ---> 81     estimator_c.fit(X_train_scaled, y_train_c)
#      82     estimators.append(estimator_c)
#      84 # 4. Predict probabilities for each class on the single test sample
#      85 #    'normal_likelihood_logistic_noise' typically returns shape (1,2): [mean, var]
#      86 #    We'll interpret the 'mean' as a *logit*, i.e. log-odds, and do logistic transform.
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\autobnn\estimators.py:101, in _AutoBnnEstimator.fit(self, X, y)
#      93 self.net_ = models.make_model(
#      94     model_name=self.model_or_name,
#      95     likelihood_model=self.likelihood_,
#    (...)
#      98     periods=self.periods,
#      99 )
#     100 self.fit_seed_, self.predict_quantiles_seed_ = jax.random.split(self.seed)
# --> 101 self.params_, self.diagnostics_ = self._fit(
#     102     net=self.net_, seed=self.seed, x_train=X, y_train=y, **self.kwargs
#     103 )
#     104 return self
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\autobnn\training_util.py:156, in fit_bnn_map(net, seed, x_train, y_train, num_particles, **optimizer_kwargs)
#     154 optimizer_kwargs['num_particles'] = num_particles
#     155 model_seed, optimization_seed = jax.random.split(seed)
# --> 156 model = _make_bayeux_model(net, model_seed, x_train, y_train, num_particles)
#     157 res = model.optimize.optax_adam(seed=optimization_seed, **optimizer_kwargs)  # pytype: disable=attribute-error
#     158 params = res.params
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\autobnn\training_util.py:115, in _make_bayeux_model(net, seed, x_train, y_train, num_particles, for_vi)
#     111 @jax.jit
#     112 def _init(rand_seed):
#     113   return net.init(rand_seed, x_train)
# --> 115 initial_state = jax.vmap(_init)(jax.random.split(seed, num_particles))
#     116 # It is okay to reuse the initial_state[0] as the test point, as Bayeux
#     117 # only uses it to figure out the treedef.
#     118 test_point = jax.tree_map(lambda t: t[0], initial_state)
#
#     [... skipping hidden 21 frame]
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\autobnn\training_util.py:113, in _make_bayeux_model.<locals>._init(rand_seed)
#     111 @jax.jit
#     112 def _init(rand_seed):
# --> 113   return net.init(rand_seed, x_train)
#
#     [... skipping hidden 12 frame]
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\autobnn\operators.py:110, in MultipliableBnnOperator.setup(self)
#     108   for b in self.bnns:
#     109     assert not getattr(b, 'going_to_be_multiplied', False)
# --> 110 super().setup()
#
#     [... skipping hidden 2 frame]
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\autobnn\operators.py:43, in BnnOperator.setup(self)
#      41 def setup(self):
#      42   assert self.bnns, 'Forgot to pass `bnns` keyword argument?'
# ---> 43   super().setup()
#
#     [... skipping hidden 2 frame]
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\autobnn\bnn.py:102, in BayesianModule.setup(self)
#     100 if not hasattr(self, k):
#     101   try:
# --> 102     setattr(self, k, self.param(k, make_sample_func(v), 1))
#     103   except flax.errors.NameInUseError:
#     104     # Sometimes subclasses will have parameters where the
#     105     # parameter name doesn't exactly correspond to the name of
#    (...)
#     109     # trying to call self.params and having it fail with NameInUseError.
#     110     # (For example, self.variables doesn't exist at setup() time.)
#     111     pass
#
#     [... skipping hidden 2 frame]
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\autobnn\bnn.py:92, in BayesianModule.setup.<locals>.make_sample_func.<locals>.sample_func(key, shape)
#      91 def sample_func(key, shape):
# ---> 92   return dist.sample(sample_shape=shape, seed=key)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\jax\distributions\distribution.py:1205, in Distribution.sample(self, sample_shape, seed, name, **kwargs)
#    1190 """Generate samples of the specified shape.
#    1191
#    1192 Note that a call to `sample()` without arguments will generate a single
#    (...)
#    1202   samples: a `Tensor` with prepended dimensions `sample_shape`.
#    1203 """
#    1204 with self._name_and_control_scope(name):
# -> 1205   return self._call_sample_n(sample_shape, seed, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\jax\distributions\transformed_distribution.py:338, in _TransformedDistribution._call_sample_n(self, sample_shape, seed, **kwargs)
#     333 x = self._maybe_broadcast_distribution_batch_shape().sample(
#     334     sample_shape=sample_shape, seed=seed, **distribution_kwargs)
#     335 # Apply the bijector's forward transformation. For caching to
#     336 # work, it is imperative that this is the last modification to the
#     337 # returned result.
# --> 338 return self.bijector.forward(x, **bijector_kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\interpreters\inverse\bijector_extensions.py:97, in patch_bijector.<locals>.forward(self, x, **kwargs)
#      96 def forward(self, x, **kwargs):
# ---> 97   return bijector_bind(self, x, direction='forward', **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\interpreters\inverse\bijector_extensions.py:80, in patch_bijector.<locals>.bijector_bind(bijector, x, **kwargs)
#      79 def bijector_bind(bijector, x, **kwargs):
# ---> 80   return primitive.initial_style_bind(
#      81       bijector_p,
#      82       direction=kwargs['direction'],
#      83       num_bijector=len(tree_util.tree_leaves(bijector)),
#      84       bijector_name=bijector.__class__.__name__)(_bijector)(bijector, x,
#      85                                                             **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\primitive.py:189, in initial_style_bind.<locals>.bind.<locals>.wrapped(*args, **kwargs)
#     187 def wrapped(*args, **kwargs):
#     188   """Runs a function and binds it to a call primitive."""
# --> 189   jaxpr, (in_tree, out_tree) = trace_util.stage(
#     190       f, dynamic=True)(*args, **kwargs)
#     191   flat_args = tree_util.tree_leaves(args)
#     192   outs = prim.bind(
#     193       *it.chain(jaxpr.literals, flat_args),
#     194       jaxpr=jaxpr.jaxpr,
#    (...)
#     197       num_consts=len(jaxpr.literals),
#     198       **params)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\trace_util.py:65, in stage.<locals>.wrapped(*args, **kwargs)
#      63 flat_avals = safe_map(get_shaped_aval, flat_args)
#      64 if dynamic:
# ---> 65   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(
#      66       flat_fun,
#      67       flat_avals)
#      68 else:
#      69   pvals = [pe.PartialVal.unknown(aval) for aval in flat_avals]
#
#     [... skipping hidden 5 frame]
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\interpreters\inverse\bijector_extensions.py:90, in patch_bijector.<locals>._bijector(bij, x, **kwargs)
#      88 direction = kwargs.pop('direction', 'forward')
#      89 if direction == 'forward':
# ---> 90   return old_forward(bij, x, **kwargs)
#      91 elif direction == 'inverse':
#      92   return old_inverse(bij, x, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\interpreters\inverse\bijector_extensions.py:97, in patch_bijector.<locals>.forward(self, x, **kwargs)
#      96 def forward(self, x, **kwargs):
# ---> 97   return bijector_bind(self, x, direction='forward', **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\interpreters\inverse\bijector_extensions.py:80, in patch_bijector.<locals>.bijector_bind(bijector, x, **kwargs)
#      79 def bijector_bind(bijector, x, **kwargs):
# ---> 80   return primitive.initial_style_bind(
#      81       bijector_p,
#      82       direction=kwargs['direction'],
#      83       num_bijector=len(tree_util.tree_leaves(bijector)),
#      84       bijector_name=bijector.__class__.__name__)(_bijector)(bijector, x,
#      85                                                             **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\primitive.py:189, in initial_style_bind.<locals>.bind.<locals>.wrapped(*args, **kwargs)
#     187 def wrapped(*args, **kwargs):
#     188   """Runs a function and binds it to a call primitive."""
# --> 189   jaxpr, (in_tree, out_tree) = trace_util.stage(
#     190       f, dynamic=True)(*args, **kwargs)
#     191   flat_args = tree_util.tree_leaves(args)
#     192   outs = prim.bind(
#     193       *it.chain(jaxpr.literals, flat_args),
#     194       jaxpr=jaxpr.jaxpr,
#    (...)
#     197       num_consts=len(jaxpr.literals),
#     198       **params)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\trace_util.py:65, in stage.<locals>.wrapped(*args, **kwargs)
#      63 flat_avals = safe_map(get_shaped_aval, flat_args)
#      64 if dynamic:
# ---> 65   jaxpr, _, consts = pe.trace_to_jaxpr_dynamic(
#      66       flat_fun,
#      67       flat_avals)
#      68 else:
#      69   pvals = [pe.PartialVal.unknown(aval) for aval in flat_avals]
#
#     [... skipping hidden 5 frame]
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\interpreters\inverse\bijector_extensions.py:90, in patch_bijector.<locals>._bijector(bij, x, **kwargs)
#      88 direction = kwargs.pop('direction', 'forward')
#      89 if direction == 'forward':
# ---> 90   return old_forward(bij, x, **kwargs)
#      91 elif direction == 'inverse':
#      92   return old_inverse(bij, x, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\jax\bijectors\bijector.py:1327, in Bijector.forward(self, x, name, **kwargs)
#    1311 def forward(self, x, name='forward', **kwargs):
#    1312   """Returns the forward `Bijector` evaluation, i.e., X = g(Y).
#    1313
#    1314   Args:
#    (...)
#    1325     NotImplementedError: if `_forward` is not implemented.
#    1326   """
# -> 1327   return self._call_forward(x, name, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\jax\bijectors\bijector.py:1309, in Bijector._call_forward(self, x, name, **kwargs)
#    1307 if not self._is_injective:  # No caching for non-injective
#    1308   return self._forward(x, **kwargs)
# -> 1309 return self._cache.forward(x, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\jax\internal\cache_util.py:334, in BijectorCache.forward(self, x, **kwargs)
#     323 def forward(self, x, **kwargs):
#     324   """Invokes the 'forward' transformation, or looks up previous results.
#     325
#     326   Args:
#    (...)
#     332     The output of the bijector's `_forward` method, or a cached result.
#     333   """
# --> 334   return self._lookup(x, self._forward_name, self._inverse_name, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\jax\internal\cache_util.py:493, in BijectorCache._lookup(self, input, forward_name, inverse_name, **kwargs)
#     487   output = output_ref()
#     488 else:
#     489   # Get the output structure, and declare a
#     490   # weakref to clear it from the cache once it gets GCed
#     491   output = nest.map_structure(
#     492       _containerize,
# --> 493       self._invoke(input, forward_name, kwargs, attrs))
#     494   output_ref = WeakStructRef(
#     495       output,
#     496       subkey=(self.bijector, self.bijector_class, inverse_name, kwargs),
#     497       callback=self.storage.maybe_del)
#     498   # Set the input->output mapping.
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\jax\internal\cache_util.py:532, in BijectorCache._invoke(self, input, fn_name, kwargs, attributes)
#     530 def _invoke(self, input, fn_name, kwargs, attributes):  # pylint: disable=unused-argument
#     531   """Invokes the wrapped function. Override to customize behavior."""
# --> 532   return getattr(self.bijector, fn_name)(input, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\substrates\jax\bijectors\softplus.py:141, in Softplus._forward(self, x)
#     139 def _forward(self, x):
#     140   if self.hinge_softness is None:
# --> 141     y = _stable_grad_softplus(x)
#     142   else:
#     143     hinge_softness = tf.cast(self.hinge_softness, x.dtype)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\backend\jax\_utils.py:62, in copy_docstring.<locals>.wrap(***failed resolving arguments***)
#      59 @wrapt.decorator
#      60 def wrap(wrapped, instance, args, kwargs):
#      61   del instance, wrapped
# ---> 62   return new_fn(*args, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_probability\python\internal\backend\jax\numpy_math.py:983, in _softplus(x, name)
#     978 if not JAX_MODE:
#     979   # This is effectively inlining jax.nn.softplus, which is (currently)
#     980   # defined as np.logaddexp(x, 0.).
#     981   # Both are numerically fine (see discussion in b/146563881).
#     982   return np.log1p(np.exp(-np.abs(x))) + np.maximum(x, 0.)
# --> 983 return jax.nn.softplus(x)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\interpreters\inverse\custom_inverse.py:54, in CustomInverse.__call__(self, *args, **kwargs)
#      53 def __call__(self, *args, **kwargs):
# ---> 54   return primitive.initial_style_bind(self.prim)(self.func)(
#      55       *args, **kwargs)
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\primitive.py:192, in initial_style_bind.<locals>.bind.<locals>.wrapped(*args, **kwargs)
#     189 jaxpr, (in_tree, out_tree) = trace_util.stage(
#     190     f, dynamic=True)(*args, **kwargs)
#     191 flat_args = tree_util.tree_leaves(args)
# --> 192 outs = prim.bind(
#     193     *it.chain(jaxpr.literals, flat_args),
#     194     jaxpr=jaxpr.jaxpr,
#     195     in_tree=in_tree,
#     196     out_tree=out_tree,
#     197     num_consts=len(jaxpr.literals),
#     198     **params)
#     199 return tree_util.tree_unflatten(out_tree, outs)
#
#     [... skipping hidden 6 frame]
#
# File c:\Users\Cybergate\AppData\Local\Programs\Python\Python310\lib\site-packages\oryx\core\primitive.py:127, in FlatPrimitive.__init__.<locals>._abstract(*flat_avals, **params)
